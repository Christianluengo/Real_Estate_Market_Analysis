# %%
import leafmap.kepler as leafmap
import geopandas as gpd
from keplergl import KeplerGl
import pandas as pd

# %%
m = leafmap.Map(center=[40, -3.7], zoom=5, height=600, widescreen=False)
m
# Out:
# Map(config={'version': 'v1', 'config': {'mapState': {'latitude': 40, 'longitude': -3.7, 'zoom': 5, 'bearing': …

# %%
m = leafmap.Map(center=[37.7621, -122.4143], zoom=12)
in_csv = (
    'https://raw.githubusercontent.com/giswqs/leafmap/master/examples/data/hex_data.csv'
)
config = 'https://raw.githubusercontent.com/giswqs/leafmap/master/examples/data/hex_config.json'
m.add_csv(in_csv, layer_name="hex_data", config=config)
m
# Out:
# Map(config={'version': 'v1', 'config': {'visState': {'layers': [{'type': 'hexagonId', 'visualChannels': {'size…

# %%
map_3 = KeplerGl(height = 600, weight = 500, data = {"point": df}, widescreen=False)
map_3
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(data={'point':                id     subtypeId        date              region  province  \
# 0       1…

# %%
df = pd.read_csv("../Data/dataset_kepler.csv")

# %%
df
# Out:
#                id     subtypeId        date  \
# 0       162758656          Piso  2022-02-24
# 1       162594835         Atico  2022-02-09
# 2       163020819   Apartamento  2022-03-23
# 3       159744043  Casa adosada  2021-04-19
# 4       160923698        Chalet  2021-08-09
# ...           ...           ...         ...
# 149243  160653289        Chalet  2021-07-09
# 149244  159105010        Chalet  2021-03-02
# 149245  162201587         Atico  2021-12-27
# 149246  161660920          Piso  2021-10-26
# 149247  161669119        Chalet  2021-10-27
#
#                                         advertiser  \
# 0                   NOVACASA ALBACETE INMOBILIARIA
# 1                               CAMPO INMOBILIARIA
# 2                               Inmohouse Albacete
# 3                                   JVJ ALBAREALTY
# 4                              LLANOS INMOBILIARIA
# ...                                            ...
# 149243                                         NaN
# 149244                        INMOBILIARIA LA VIÑA
# 149245                     Alfa Inmobiliaria Ávila
# 149246  ROMARSA SERVICIOS INTEGRALES INMOBILIARIOS
# 149247                                         NaN
#
#                                              descriptions              region  \
# 0       NovaCasa VENDE Piso de 5 Dormitorios con Ascen...  Castilla-La Mancha
# 1       REF.-20263 CAMPO INMOBILIARIA vende precioso A...  Castilla-La Mancha
# 2       INMOHOUSE VENDE APARTAMENTO ZONA SAN PABLO ( S...  Castilla-La Mancha
# 3       Se vende magnifica casa en Valdeganga con pisc...  Castilla-La Mancha
# 4       Casa totalmente nueva, para entrar a vivir, se...  Castilla-La Mancha
# ...                                                   ...                 ...
# 149243  Estupenda finca totalmente independiente con c...     Castilla y León
# 149244  \r\nSe vende estupenda casa de dos plantas dem...     Castilla y León
# 149245  ¡OPORTUNIDAD! Alfa Inmobiliaria vende este mar...     Castilla y León
# 149246  Vivienda situada en Arenas de San Pedro (Avila...     Castilla y León
# 149247  Se vende chalet adosado de 180 m2 construidos,...     Castilla y León
#
#         province                 city  zipcode  latitude  longitude  rooms  \
# 0       Albacete     Albacete Capital     2004  38.98808  -1.866541      5
# 1       Albacete     Albacete Capital     2006  38.98234  -1.874801      3
# 2       Albacete     Albacete Capital     2006  38.99845  -1.876605      2
# 3       Albacete           Valdeganga     2150  39.13467  -1.682731      4
# 4       Albacete              La Roda     2630  39.20795  -2.156046      4
# ...          ...                  ...      ...       ...        ...    ...
# 149243     Ávila               Muñico     5145  40.70689  -5.027555      2
# 149244     Ávila       Pedro Bernardo     5470  40.25021  -4.928972      4
# 149245     Ávila        Ávila Capital     5002  40.65064  -4.699001      1
# 149246     Ávila  Arenas de San Pedro     5400  40.20869  -5.083589      1
# 149247     Ávila            Candeleda     5480  40.15072  -5.239482      4
#
#         bathrooms  surface  energy_certificate  antiquity  floor  surfaceland  \
# 0               2      140                   7          6      0            0
# 1               2       80                   7          0      8            0
# 2               1       65                   7          0      9            0
# 3               3      246                   7          4      0            0
# 4               2      205                   5          0      0            0
# ...           ...      ...                 ...        ...    ...          ...
# 149243          1      300                   2          0      0          300
# 149244          2      182                   7          8      0            0
# 149245          1       44                   7          5     10            0
# 149246          1       40                   5          0      6            0
# 149247          3      180                   1          0      0          180
#
#          price         €/m2
# 0       135000   964.285714
# 1       175000  2187.500000
# 2       134000  2061.538462
# 3       150000   609.756098
# 4       135000   658.536585
# ...        ...          ...
# 149243   38000    63.333333
# 149244  220000  1208.791209
# 149245   55000  1250.000000
# 149246   33000   825.000000
# 149247  182500   506.944444
#
# [149248 rows x 20 columns]
